# %% [markdown]
# <a href="https://colab.research.google.com/github/PhatLe7/PhatLe7/blob/main/Introduce_To_PyTorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
2+2
# Out:
# 4

# %%
import torch

# %%
# !pip list

# %% [markdown]
# **List**
